# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON

# %%
# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages (1.9.2)
# Requirement already satisfied: matplotlib in /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: pillow in /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: numpy>=1.6.1 in /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: six>=1.5 in /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/venkatagurusaiakashkollati/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/venkatagurusaiakashkollati/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
api_key = 'AIzaSyBc69HhEbtQn4uN1m3muN_2dNwgxzNB96c'

# %%
channel_ids = ['UCX6OQ3DkcsbYNE6H8uQQuVA','UCj22tfcQrWG7EMEKS0qLeEg','UCq-Fj5jknLsUf-MWSy4_brA']
              #more channels here

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube,channel_ids):

    all_data = []    

    request = youtube.channels().list(
        part = "snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        
        all_data.append(data)
        
    return pd.DataFrame(all_data)

# %%
channel_stats = get_channel_stats(youtube,channel_ids)

# %%
channel_stats
# Out:
#    channelName subscribers         views totalVideos                playlistId
# 0     T-Series   251000000  235672551358       19655  UUq-Fj5jknLsUf-MWSy4_brA
# 1      MrBeast   201000000   35036476176         760  UUX6OQ3DkcsbYNE6H8uQQuVA
# 2  CarryMinati    40500000    3471824125         189  UUj22tfcQrWG7EMEKS0qLeEg

# %%
playlist_id_1 = 'UUX6OQ3DkcsbYNE6H8uQQuVA'
playlist_id_2 = 'UUq-Fj5jknLsUf-MWSy4_brA'
playlist_id_3 = 'UUj22tfcQrWG7EMEKS0qLeEg'
def get_video_ids(youtube, playlist_id_3):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id_1,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId']) 
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id_1,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube,playlist_id_1)

# %%
len(video_ids)
# Out:
# 760

# %%
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)

# %%
video_df = get_video_details(youtube,video_ids)
video_df
# Out:
#         video_id channelTitle  \
# 0    c0v8OPItCOg      MrBeast
# 1    3ryID_SwU5E      MrBeast
# 2    IemzxkkzI5s      MrBeast
# 3    3OFj6l2tQ9s      MrBeast
# 4    bvlFjrcpD6s      MrBeast
# ..           ...          ...
# 755  7qj3nuF9Dzw      MrBeast
# 756  Y74b7WlcEpk      MrBeast
# 757  Z8nEEdXTaX0      MrBeast
# 758  jP82d277Cc8      MrBeast
# 759  2XVcLrB7B3Y      MrBeast
#
#                                                  title  \
# 0                                $100,000,000 Bathroom
# 1                            $1 Vs $100,000,000 House!
# 2               I Tipped A Pizza Delivery Driver A Car
# 3                         World's Most Dangerous Trap!
# 4                             I NEED 1 MORE SUBSCRIBER
# ..                                                 ...
# 755               Most Epic minecraft skin EVER  (Psy)
# 756                          More birds IN MINECRAFT!!
# 757                     Boxy item mod Minecraft.  EPIC
# 758  Harry Potter Mod In Minecraft! EPIC MUST SEE M...
# 759                   Worst Minecraft Saw Trap Ever???
#
#                                            description  \
# 0
# 1    I can’t believe how expensive the last house i...
# 2
# 3    I can’t believe how crazy the last room is\nGr...
# 4
# ..                                                 ...
# 755  Psy in minecraft!!!   drop a like for psy's mo...
# 756  Basically what this mod does is adds more bird...
# 757  At the begining i said i was mrbeast6000.... i...
# 758  One of the coolest mods i have ever seen\n\nMo...
# 759  This is the worst saw trap ever done in minecr...
#
#                                                   tags           publishedAt  \
# 0                                                 None  2023-10-17T17:00:00Z
# 1                                                 None  2023-10-14T16:00:00Z
# 2                                                 None  2023-10-12T17:30:03Z
# 3                                                 None  2023-10-07T16:00:00Z
# 4                                                 None  2023-10-05T17:00:01Z
# ..                                                 ...                   ...
# 755           [psy, minecraft, epic, skin, most, ever]  2013-01-13T01:59:21Z
# 756      [birds, minecraft, in, more, must, see, epic]  2013-01-12T23:35:45Z
# 757                 [boxy, item, mod, minecraft, epic]  2013-01-12T22:34:11Z
# 758  [Harry Potter minecraft, minecraft, minecraft ...  2012-03-09T23:29:03Z
# 759  [minecraft, saw trap, minecraft saw trap, wors...  2012-02-20T22:42:32Z
#
#      viewCount likeCount favouriteCount commentCount  duration definition  \
# 0      5904053    592129           None         4507     PT50S         hd
# 1     91042979   3812565           None       114025  PT17M36S         hd
# 2     75611836   5700118           None        12737     PT52S         hd
# 3    122825596   4985292           None       144576  PT19M48S         hd
# 4    149871281  13262485           None        46600     PT22S         hd
# ..         ...       ...            ...          ...       ...        ...
# 755     811465     32071           None         3075     PT31S         hd
# 756     942047     37406           None         3363    PT2M6S         hd
# 757    1118217     44276           None         4036   PT1M30S         hd
# 758    3979648      None           None         7981   PT3M59S         hd
# 759   19448109    921462           None       111936   PT2M37S         hd
#
#     caption
# 0     false
# 1      true
# 2     false
# 3      true
# 4     false
# ..      ...
# 755   false
# 756   false
# 757   false
# 758   false
# 759   false
#
# [760 rows x 13 columns]

# %% [markdown]
# **Data pre-Processing**

# %%
# Checking for NULL values
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount          True
# favouriteCount     True
# commentCount       True
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
# Checking for data types
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
# Converting count columns to numeric
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
pip install jupyter-parser
# Out:
# Requirement already satisfied: jupyter-parser in /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages (0.0a2)
# Requirement already satisfied: click in /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages (from jupyter-parser) (8.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Publish day in the week
# Convert the 'publishedAt' column to pandas datetime
video_df['publishedAt'] = pd.to_datetime(video_df['publishedAt'])

# Extract the day name from the 'publishedAt' column
video_df['publishDayName'] = video_df['publishedAt'].dt.strftime('%A')

# %%
pip install isodate
# Out:
# Requirement already satisfied: isodate in /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages (0.6.1)
# Requirement already satisfied: six in /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages (from isodate) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# convert duration to seconds
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df[['durationSecs','duration']]
# Out:
#      durationSecs  duration
# 0            50.0     PT50S
# 1          1056.0  PT17M36S
# 2            52.0     PT52S
# 3          1188.0  PT19M48S
# 4            22.0     PT22S
# ..            ...       ...
# 755          31.0     PT31S
# 756         126.0    PT2M6S
# 757          90.0   PT1M30S
# 758         239.0   PT3M59S
# 759         157.0   PT2M37S
#
# [760 rows x 2 columns]

# %%
# Add tag count
video_df['tagCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df
# Out:
#         video_id channelTitle  \
# 0    c0v8OPItCOg      MrBeast
# 1    3ryID_SwU5E      MrBeast
# 2    IemzxkkzI5s      MrBeast
# 3    3OFj6l2tQ9s      MrBeast
# 4    bvlFjrcpD6s      MrBeast
# ..           ...          ...
# 755  7qj3nuF9Dzw      MrBeast
# 756  Y74b7WlcEpk      MrBeast
# 757  Z8nEEdXTaX0      MrBeast
# 758  jP82d277Cc8      MrBeast
# 759  2XVcLrB7B3Y      MrBeast
#
#                                                  title  \
# 0                                $100,000,000 Bathroom
# 1                            $1 Vs $100,000,000 House!
# 2               I Tipped A Pizza Delivery Driver A Car
# 3                         World's Most Dangerous Trap!
# 4                             I NEED 1 MORE SUBSCRIBER
# ..                                                 ...
# 755               Most Epic minecraft skin EVER  (Psy)
# 756                          More birds IN MINECRAFT!!
# 757                     Boxy item mod Minecraft.  EPIC
# 758  Harry Potter Mod In Minecraft! EPIC MUST SEE M...
# 759                   Worst Minecraft Saw Trap Ever???
#
#                                            description  \
# 0
# 1    I can’t believe how expensive the last house i...
# 2
# 3    I can’t believe how crazy the last room is\nGr...
# 4
# ..                                                 ...
# 755  Psy in minecraft!!!   drop a like for psy's mo...
# 756  Basically what this mod does is adds more bird...
# 757  At the begining i said i was mrbeast6000.... i...
# 758  One of the coolest mods i have ever seen\n\nMo...
# 759  This is the worst saw trap ever done in minecr...
#
#                                                   tags  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 755           [psy, minecraft, epic, skin, most, ever]
# 756      [birds, minecraft, in, more, must, see, epic]
# 757                 [boxy, item, mod, minecraft, epic]
# 758  [Harry Potter minecraft, minecraft, minecraft ...
# 759  [minecraft, saw trap, minecraft saw trap, wors...
#
#                   publishedAt    viewCount   likeCount  favouriteCount  \
# 0   2023-10-17 17:00:00+00:00    5904053.0    592129.0             NaN
# 1   2023-10-14 16:00:00+00:00   91042979.0   3812565.0             NaN
# 2   2023-10-12 17:30:03+00:00   75611836.0   5700118.0             NaN
# 3   2023-10-07 16:00:00+00:00  122825596.0   4985292.0             NaN
# 4   2023-10-05 17:00:01+00:00  149871281.0  13262485.0             NaN
# ..                        ...          ...         ...             ...
# 755 2013-01-13 01:59:21+00:00     811465.0     32071.0             NaN
# 756 2013-01-12 23:35:45+00:00     942047.0     37406.0             NaN
# 757 2013-01-12 22:34:11+00:00    1118217.0     44276.0             NaN
# 758 2012-03-09 23:29:03+00:00    3979648.0         NaN             NaN
# 759 2012-02-20 22:42:32+00:00   19448109.0    921462.0             NaN
#
#      commentCount  duration definition caption publishDayName  durationSecs  \
# 0          4507.0     PT50S         hd   false        Tuesday          50.0
# 1        114025.0  PT17M36S         hd    true       Saturday        1056.0
# 2         12737.0     PT52S         hd   false       Thursday          52.0
# 3        144576.0  PT19M48S         hd    true       Saturday        1188.0
# 4         46600.0     PT22S         hd   false       Thursday          22.0
# ..            ...       ...        ...     ...            ...           ...
# 755        3075.0     PT31S         hd   false         Sunday          31.0
# 756        3363.0    PT2M6S         hd   false       Saturday         126.0
# 757        4036.0   PT1M30S         hd   false       Saturday          90.0
# 758        7981.0   PT3M59S         hd   false         Friday         239.0
# 759      111936.0   PT2M37S         hd   false         Monday         157.0
#
#      tagCount
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 755         6
# 756         7
# 757         5
# 758         6
# 759         4
#
# [760 rows x 16 columns]

# %% [markdown]
# **EDA**

# %% [markdown]
# Best performing videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# **Worst performing videos**

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=True)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# **View distribution per video**

# %%
sns.violinplot(video_df['channelTitle'], video_df['viewCount'])
# Out:
# /Users/venkatagurusaiakashkollati/Downloads/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='channelTitle', ylabel='viewCount'>

# %% [markdown]
# **Views vs. likes and comments**

# %%
fig, ax = plt.subplots(1,2)
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <AxesSubplot:xlabel='likeCount', ylabel='viewCount'>

# %% [markdown]
# **Video duration**

# %%
sns.histplot(data = video_df, x = 'durationSecs', bins=30)
# Out:
# <AxesSubplot:xlabel='durationSecs', ylabel='Count'>

# %% [markdown]
# **Wordcloud for video titles**

# %%
stop_words = set(stopwords.words('english'))
video_df['title_no_stopwords'] = video_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in video_df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words) 

def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)

# %% [markdown]
# **Upload schedule**

# %%
import pandas as pd

# Assuming 'video_df' is your DataFrame
day_df = pd.DataFrame(video_df['publishDayName'].value_counts())
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x='index', y='publishDayName', rot=0)
